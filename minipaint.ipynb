# %%
# !pip install opencv-python mediapipe numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (4.11.0.86)
# Requirement already satisfied: mediapipe in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (0.10.21)
# Requirement already satisfied: numpy in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (1.26.4)
# Requirement already satisfied: absl-py in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (25.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (25.9.23)
# Requirement already satisfied: jax in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: jaxlib in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: matplotlib in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (3.10.7)
# Requirement already satisfied: opencv-contrib-python in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: sentencepiece in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from mediapipe) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.23)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\.conda\envs\handdraw\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
import cv2
import mediapipe as mp
import numpy as np
import time

# %%
mp_hands=mp.solutions.hands 
mp_drawing=mp.solutions.drawing_utils
hands= mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)

#red in BGR
draw_color= (0,0,255)
brush_thickness =8
eraser_thickness=40

#screen top having colour choices
colors = {
    'Red': (0,0,255),
    'Green': (0,255,0),
    'Blue': (255,0,0),
    'Eraser': (0,0,0)
}

# %%
cap=cv2.VideoCapture(0)
canvas=None
prev_x,prev_y=0,0
last_seen= time.time()  #auto stop

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame=cv2.flip(frame, 1)
    h,w,_=frame.shape
    if canvas is None:
        canvas= np.zeros_like(frame)

    rgb=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result =hands.process(rgb)

    #draw color buttons at top
    cv2.rectangle(frame, (0,0),(w,70),(50, 50,50),-1)
    x_pos = 10
    for color_name, color_val in colors.items():
        cv2.rectangle(frame, (x_pos, 10), (x_pos + 100, 60), color_val, -1)
        cv2.putText(frame, color_name, (x_pos + 10, 45),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
        x_pos += 120

    if result.multi_hand_landmarks:
        last_seen = time.time()  #time is reset when a hand is detected

        for hand_landmarks in result.multi_hand_landmarks:
            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

            #get index & middle finger postn
            x1 = int(hand_landmarks.landmark[8].x * w)
            y1 = int(hand_landmarks.landmark[8].y * h)
            x2 = int(hand_landmarks.landmark[12].x * w)
            y2 = int(hand_landmarks.landmark[12].y * h)
            distance = np.hypot(x2 - x1, y2 - y1)

            #check if finger is selecting color from top
            if y1 < 70:
                if 10 < x1 < 110:
                    draw_color = (0, 0, 255)#red
                elif 130 < x1 < 230:
                    draw_color = (0, 255, 0) #green
                elif 250 < x1 < 350:
                    draw_color = (255, 0, 0) #blue
                elif 370 < x1 < 470:
                    draw_color = (0, 0, 0)  #eraser
                prev_x, prev_y = 0, 0  #tracking prev locations for smooth lines

            #draw
            elif distance > 40:
                cv2.circle(frame, (x1, y1), 8, draw_color, -1)
                if prev_x == 0 and prev_y == 0:
                    prev_x, prev_y = x1, y1
                thickness = eraser_thickness if draw_color == (0, 0, 0) else brush_thickness
                cv2.line(canvas, (prev_x, prev_y), (x1, y1), draw_color, thickness)
                prev_x, prev_y = x1, y1
            else:
                prev_x, prev_y = 0, 0

    #autostop timer
    elif time.time()-last_seen>20:
        print("No hand detected for 20 seconds...stopping automatically.")
        break

    #combine canvas &frame
    gray = cv2.cvtColor(canvas,cv2.COLOR_BGR2GRAY)
    _, inv = cv2.threshold(gray, 20, 255, cv2.THRESH_BINARY_INV)#threshold step
    inv = cv2.cvtColor(inv, cv2.COLOR_GRAY2BGR)
    frame = cv2.bitwise_and(frame, inv)
    frame = cv2.bitwise_or(frame, canvas)

    cv2.imshow("AI Hand Painter", frame)
    cv2.imshow("Canvas", canvas)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quit command received.. exiting.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# No hand detected for 20 seconds...stopping automatically.
